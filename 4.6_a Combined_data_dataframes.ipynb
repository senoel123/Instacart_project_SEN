# %%
#import libaries
 
import pandas as pd
import numpy as np
import os

# %%
#read in pickle file

orders_products_combined= pd.read_pickle(r"C:\Users\senoe\OneDrive\SEN Docs\Data Sci Job Applications\CareerFoundry\Datasets\original data\orders_products_combined.pkl")

# %%
#look at shape of df

orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
#read in products cleaned df

df_prods_clean1= pd.read_csv(r"C:\Users\senoe\OneDrive\SEN Docs\Data Sci Job Applications\CareerFoundry\Datasets\Prepared data\products_checked.csv")

# %%
df_prods_clean1.shape
# Out:
# (49672, 5)

# %%
df_prods_clean1.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# # Merge
#
# The two dataframe can be merged on 'product_id'.  I will use a 'inner join' sp that I can keep information from the left dataframe) ('orders_products_combined') with any information in the right dataframe ('df_product_clean1')
# that can be mapped back to the dataframe on the left.

# %%
orders_products_combined_new = orders_products_combined.merge(df_prods_clean1, on='product_id')

# %%
orders_products_combined_new.shape
# Out:
# (32404859, 15)

# %%
orders_products_combined_new['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Test merge without overwriting
pd.merge(orders_products_combined,df_prods_clean1, on = ['product_id'])
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 32404854   1320836   202557    prior            17          2
# 32404855     31526   202557    prior            18          5
# 32404856    758936   203436    prior             1          2
# 32404857   2745165   203436    prior             2          3
# 32404858   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
#export DataFrame to CSV file df 
orders_products_combined_new.to_csv(r"C:\Users\senoe\OneDrive\SEN Docs\Data Sci Job Applications\CareerFoundry\Datasets\Prepared data\orders_products_merged1.csv", index=False)
